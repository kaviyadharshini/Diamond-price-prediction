# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'D:\Users\Sharanya N Rao\Downloads\diamonds.csv.zip')
dataset
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
df_dataset = pd.DataFrame()
n_cut ={'Ideal':0,'Premium':1,'Good':2,'Very Good':3,'Fair':4}
n_color ={'D':0,'E':1,'F':2,'G':3,'H':4,'I':5,'J':6}
n_clarity ={'I1':0,'IF':1,'SI1':2,'SI2':3,'VS1':4,'VS2':5,'VVS1':6,'VVS2':7}

# %%
def clean_cut(m):
    return n_cut[m]
def clean_color(m):
    return n_color[m]
def clean_clarity(m):
    return n_clarity[m]
df_dataset['carat']=dataset['carat']
df_dataset['cut']=dataset['cut'].apply(clean_cut)
df_dataset['color']=dataset['color'].apply(clean_color)
df_dataset['clarity']=dataset['clarity'].apply(clean_clarity)
df_dataset['depth']=dataset['depth']
df_dataset['table']=dataset['table']
df_dataset['x']=dataset['x']
df_dataset['y']=dataset['y']
df_dataset['z']=dataset['z']
df_dataset['price']=dataset['price']
print(df_dataset.head(10))
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0.23    0      1        3   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21    1      1        2   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23    2      1        4   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29    1      5        5   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31    2      6        3   63.3   58.0  4.34  4.35  2.75    335
# 5   0.24    3      6        7   62.8   57.0  3.94  3.96  2.48    336
# 6   0.24    3      5        6   62.3   57.0  3.95  3.98  2.47    336
# 7   0.26    3      4        2   61.9   55.0  4.07  4.11  2.53    337
# 8   0.22    4      1        5   65.1   61.0  3.87  3.78  2.49    337
# 9   0.23    3      4        4   59.4   61.0  4.00  4.05  2.39    338

# %%
m = df_dataset.iloc[:, 0:10].values
m
# Out:
# array([[2.300e-01, 0.000e+00, 1.000e+00, ..., 3.980e+00, 2.430e+00,
#         3.260e+02],
#        [2.100e-01, 1.000e+00, 1.000e+00, ..., 3.840e+00, 2.310e+00,
#         3.260e+02],
#        [2.300e-01, 2.000e+00, 1.000e+00, ..., 4.070e+00, 2.310e+00,
#         3.270e+02],
#        ...,
#        [7.000e-01, 3.000e+00, 0.000e+00, ..., 5.680e+00, 3.560e+00,
#         2.757e+03],
#        [8.600e-01, 1.000e+00, 4.000e+00, ..., 6.120e+00, 3.740e+00,
#         2.757e+03],
#        [7.500e-01, 0.000e+00, 0.000e+00, ..., 5.870e+00, 3.640e+00,
#         2.757e+03]])

# %%
n = dataset.iloc[:, 10].values
n
# Out:
# array([2.43, 2.31, 2.31, ..., 3.56, 3.74, 3.64])

# %%
from sklearn.model_selection import train_test_split
m_train, m_test, n_train, n_test = train_test_split(m,n,test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor()
regressor.fit(m_train,n_train)
# Out:
# C:\Users\Sharanya N Rao\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
test_score =regressor.score(m_test,n_test)
training_score =regressor.score(m_train,n_train)
train_error =1-training_score
print("training score:",training_score,"\ntraining error:",train_error)
# Out:
# training score: 0.9947069390800947
# training error: 0.005293060919905335

# %%
from sklearn.metrics import mean_squared_error,r2_score
n_pred=regressor.predict(m_test)
r2_test=r2_score(n_test,n_pred)

# %%
plt.scatter(n_test,n_pred,color='red')
plt.title('Random Forest Regression')
plt.xlabel('actual charges')
plt.ylabel('predicted charges')
plt.show()
